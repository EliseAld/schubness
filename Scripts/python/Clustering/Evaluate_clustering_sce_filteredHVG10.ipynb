# %%
import sys
sys.path.append('..')
import os
import sklearn.metrics.cluster
import sklearn.cluster
import seaborn as sns
import scanpy as sc
import sklearn as sk
from sklearn.neighbors import NearestNeighbors
import matplotlib as mpl
from matplotlib import pyplot as plt
import skdim
import seaborn as sns
import time
import numpy as np
import pandas as pd
import pickle
import rpy2.robjects as ro
import rpy2.robjects.numpy2ri
import rpy2.robjects.packages as rpackages
import utils
import anndata2ri
import gc
import benchmark_common_functions
from itertools import product

anndata2ri.activate()
ro.numpy2ri.activate()
readRDS = ro.r['readRDS']
# %load_ext rpy2.ipython

# %%
rootdir = '../data/DuoClustering2018/sce_filteredHVG10/'
resdir = '../results/DuoClustering2018/sce_filteredHVG10/'

fnames = os.listdir(rootdir)
fnames = [f for f in fnames if 'sce' in f and '.rds' in f]

#get_res_path = lambda fname: f'{resdir}{fname}_norm{do_norm}_log{do_log}_pca{do_pca}_ncomps{n_comps}_{metric}_weighted{weighted}_knn{n_neighbors}_seed{seed}.pkl'
#get_res_path_orig = lambda fname: f'{resdir}{fname}_orig_pca{do_pca}_ncomps{n_comps}_{metric}_weighted{weighted}_knn{n_neighbors}_seed{seed}.pkl'
get_res_path = lambda fname: f'{resdir}{fname}_norm{do_norm}_scale{norm_scale}_log{do_log}_pca{do_pca}_ncomps{n_comps}_{metric}_weighted{weighted}_knn_sqrt_seed{seed}.pkl'
get_res_path_orig = lambda fname: f'{resdir}{fname}_orig_pca{do_pca}_ncomps{n_comps}_{metric}_weighted{weighted}_knn_sqrt_seed{seed}.pkl'

# %% [markdown]
# # Run all datasets original

# %%
#fixed params
do_norm = False
norm_scale = False
do_log = False
do_pca = True
#n_neighbors = 10
seed = 0

#vary params
metric=('cosine','euclidean')
n_comps=(25,50,100,500)
weighted=(True,)

params_list = list(product(metric,n_comps,weighted))

# %%
for metric,n_comps,weighted in params_list:
    print(metric,n_comps,weighted)
    for fname in fnames:
        if get_res_path_orig(fname[:-4]).split('/')[-1] in os.listdir(resdir):
            continue
        print('\t\t'+fname)
        adata = readRDS(rootdir+fname)
        adata.X = adata.layers['logcounts']
            
        results_dict = benchmark_common_functions.clustering_analysis(
            adata,
            true_labels = adata.obs['phenoid'],
            do_norm = do_norm,
            norm_scale=norm_scale,
            do_log = do_log,
            do_pca = do_pca,
            n_neighbors=int(round(np.sqrt(len(adata)))),
            n_clusters= adata.obs['phenoid'].nunique(),
            metric=metric,
            weighted=weighted,  #weighted adjmat for louvain/leiden clustering ?
            seed=seed,
            n_comps=n_comps
        )

        with open(get_res_path_orig(fname[:-4]),'wb') as f:
            pickle.dump(results_dict,f)
        # %xdel adata
        gc.collect()
# Out:
# cosine 25 True
# 		sce_filteredHVG10_KohTCC.rds
# 			Preprocessing done: 0.1 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.09 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_Kumar.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# R[write to console]: Loading required package: splatter
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.02 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.03 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.05 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_Trapnell.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.23 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.41 mn
# 			Base louvain/leiden clus, searching ground truth: 0.05 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.46 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.03 mn
# 			Scanpy louvain/leiden clus: 0.56 mn
# 			Louvain/leiden clus: 0.03 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.69 mn
# 			Base louvain/leiden clus, searching ground truth: 0.09 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 1.22 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.03 mn
# 			Scanpy louvain/leiden clus: 0.39 mn
# 			Louvain/leiden clus: 0.02 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.53 mn
# 			Base louvain/leiden clus, searching ground truth: 0.07 mn
# 			Scoring: 0.01 mn
# Cannot find the number of clusters
# Clustering solution from last iteration is used:7 at resolution 1.040207862854004
# 			Hubness methods full pipeline: 0.73 mn
# cosine 50 True
# 		sce_filteredHVG10_Koh.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_KohTCC.rds
# 			Preprocessing done: 0.15 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_Kumar.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 			Preprocessing done: 0.06 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.05 mn
# 		sce_filteredHVG10_Trapnell.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.2 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.52 mn
# 			Base louvain/leiden clus, searching ground truth: 0.04 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.45 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.03 mn
# 			Scanpy louvain/leiden clus: 0.58 mn
# 			Louvain/leiden clus: 0.06 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.98 mn
# 			Base louvain/leiden clus, searching ground truth: 0.1 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.86 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.26 mn
# 			Louvain/leiden clus: 0.02 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.7 mn
# 			Base louvain/leiden clus, searching ground truth: 0.02 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.8 mn
# cosine 100 True
# 		sce_filteredHVG10_Koh.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_KohTCC.rds
# 			Preprocessing done: 0.29 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.02 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.06 mn
# 		sce_filteredHVG10_Kumar.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 			Preprocessing done: 0.11 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.06 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.08 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.03 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.03 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.1 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.02 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.04 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.08 mn
# 		sce_filteredHVG10_Trapnell.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 			Preprocessing done: 0.08 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 			Preprocessing done: 0.07 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.25 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.46 mn
# 			Base louvain/leiden clus, searching ground truth: 0.04 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.5 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.04 mn
# 			Scanpy louvain/leiden clus: 0.71 mn
# 			Louvain/leiden clus: 0.04 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 1.0 mn
# 			Base louvain/leiden clus, searching ground truth: 0.07 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.78 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.33 mn
# 			Louvain/leiden clus: 0.03 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.63 mn
# 			Base louvain/leiden clus, searching ground truth: 0.15 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.62 mn
# cosine 500 True
# 		sce_filteredHVG10_Koh.rds
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.05 mn
# 		sce_filteredHVG10_KohTCC.rds
# 			Preprocessing done: 0.3 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.07 mn
# 		sce_filteredHVG10_Kumar.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 			Preprocessing done: 0.07 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.02 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.06 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.06 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.03 mn
# 			Base louvain/leiden clus, searching ground truth: 0.01 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.07 mn
# 		sce_filteredHVG10_Trapnell.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.0 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 			Preprocessing done: 0.08 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.19 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.35 mn
# 			Base louvain/leiden clus, searching ground truth: 0.03 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.74 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 			Preprocessing done: 0.11 mn
# 			Inputs generated: 0.03 mn
# 			Scanpy louvain/leiden clus: 0.69 mn
# 			Louvain/leiden clus: 0.05 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 1.25 mn
# 			Base louvain/leiden clus, searching ground truth: 0.15 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 1.64 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 			Preprocessing done: 0.17 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.28 mn
# 			Louvain/leiden clus: 0.02 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.44 mn
# 			Base louvain/leiden clus, searching ground truth: 0.08 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.98 mn
# euclidean 25 True
# 		sce_filteredHVG10_Koh.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_KohTCC.rds
# 			Preprocessing done: 0.08 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_Kumar.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_Trapnell.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.15 mn
# 			Louvain/leiden clus: 0.03 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.63 mn
# 			Base louvain/leiden clus, searching ground truth: 0.07 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.44 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.31 mn
# 			Louvain/leiden clus: 0.03 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.65 mn
# 			Base louvain/leiden clus, searching ground truth: 0.13 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.74 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.25 mn
# 			Louvain/leiden clus: 0.02 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.37 mn
# 			Base louvain/leiden clus, searching ground truth: 0.12 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.45 mn
# euclidean 50 True
# 		sce_filteredHVG10_Koh.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_KohTCC.rds
# 			Preprocessing done: 0.17 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_Kumar.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 			Preprocessing done: 0.06 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.0 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_Trapnell.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.18 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.3 mn
# 			Base louvain/leiden clus, searching ground truth: 0.03 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.66 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 			Preprocessing done: 0.08 mn
# 			Inputs generated: 0.08 mn
# 			Scanpy louvain/leiden clus: 0.51 mn
# 			Louvain/leiden clus: 0.03 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.98 mn
# 			Base louvain/leiden clus, searching ground truth: 0.08 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.79 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.22 mn
# 			Louvain/leiden clus: 0.02 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.55 mn
# 			Base louvain/leiden clus, searching ground truth: 0.1 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.56 mn
# euclidean 100 True
# 		sce_filteredHVG10_Koh.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_KohTCC.rds
# 			Preprocessing done: 0.21 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_Kumar.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 			Preprocessing done: 0.07 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.03 mn
# 			Base louvain/leiden clus, searching ground truth: 0.01 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.05 mn
# 		sce_filteredHVG10_Trapnell.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 			Preprocessing done: 0.05 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.04 mn
# 			Scanpy louvain/leiden clus: 0.16 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.36 mn
# 			Base louvain/leiden clus, searching ground truth: 0.04 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.49 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.09 mn
# 			Scanpy louvain/leiden clus: 0.37 mn
# 			Louvain/leiden clus: 0.03 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.86 mn
# 			Base louvain/leiden clus, searching ground truth: 0.1 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 1.11 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.05 mn
# 			Scanpy louvain/leiden clus: 0.23 mn
# 			Louvain/leiden clus: 0.02 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.2 mn
# 			Base louvain/leiden clus, searching ground truth: 0.08 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.64 mn
# euclidean 500 True
# 		sce_filteredHVG10_Koh.rds
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.07 mn
# 		sce_filteredHVG10_KohTCC.rds
# 			Preprocessing done: 0.25 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.03 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.08 mn
# 		sce_filteredHVG10_Kumar.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.0 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 			Preprocessing done: 0.06 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.07 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.07 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.08 mn
# 		sce_filteredHVG10_Trapnell.rds
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 			Preprocessing done: 0.04 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.0 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.02 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 			Preprocessing done: 0.07 mn
# 			Inputs generated: 0.21 mn
# 			Scanpy louvain/leiden clus: 0.14 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.32 mn
# 			Base louvain/leiden clus, searching ground truth: 0.02 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 1.52 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 			Preprocessing done: 0.1 mn
# 			Inputs generated: 0.5 mn
# 			Scanpy louvain/leiden clus: 0.32 mn
# 			Louvain/leiden clus: 0.02 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.52 mn
# 			Base louvain/leiden clus, searching ground truth: 0.06 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 3.77 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 			Preprocessing done: 0.08 mn
# 			Inputs generated: 0.27 mn
# 			Scanpy louvain/leiden clus: 0.24 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.19 mn
# 			Base louvain/leiden clus, searching ground truth: 0.03 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 2.08 mn

# %% [markdown]
# # Run all datasets

# %%
#fixed params
do_norm = False
norm_scale = False
do_log = True
do_pca = True
n_neighbors = 10
seed = 0

#vary params
metric=('cosine','euclidean')
n_comps=(25,50,100,500)
weighted=(True,False)
do_norm = ('duo','seurat','zheng17',None)
norm_scale = (True,False)
params_list = list(product(metric,n_comps,weighted,do_norm,norm_scale))

# %%
for metric,n_comps,weighted,do_norm,norm_scale in params_list:
    print(metric,n_comps,weighted,do_norm,norm_scale)
    for fname in fnames:
        if get_res_path(fname[:-4]).split('/')[-1] in os.listdir(resdir):
            continue
        print('\t\t'+fname)
        adata = readRDS(rootdir+fname)
        if 'Sim' in fname:
            adata.X = adata.layers['counts']
        results_dict = benchmark_common_functions.clustering_analysis(
            adata,
            true_labels = adata.obs['phenoid'],
            do_norm = do_norm,
            norm_scale = norm_scale,
            do_log = do_log,
            do_pca = do_pca,
            n_neighbors=n_neighbors,
            n_clusters= adata.obs['phenoid'].nunique(),
            metric=metric,
            weighted=weighted,  #weighted adjmat for louvain/leiden clustering ?
            seed=seed,
            n_comps=n_comps
        )

        with open(get_res_path(fname[:-4]),'wb') as f:
            pickle.dump(results_dict,f)
    
        # %xdel adata
        gc.collect()
# Out:
# cosine 25 True duo True
# 		sce_filteredHVG10_Koh.rds
# 		duo norm retained 4898 genes
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.09 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.01 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.05 mn
# 		sce_filteredHVG10_KohTCC.rds
# 		duo norm retained 5000 genes
# 			Preprocessing done: 0.06 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.02 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.01 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.06 mn
# 		sce_filteredHVG10_Kumar.rds
# 		duo norm retained 4516 genes
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 		duo norm retained 5000 genes
# 			Preprocessing done: 0.11 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.02 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# R[write to console]: Loading required package: splatter
# 		duo norm retained 4361 genes
# 			Preprocessing done: 0.11 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.05 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 		duo norm retained 4364 genes
# 			Preprocessing done: 0.07 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.04 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 		duo norm retained 4360 genes
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.08 mn
# 		sce_filteredHVG10_Trapnell.rds
# 		duo norm retained 4111 genes
# 			Preprocessing done: 0.0 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 		duo norm retained 5000 genes
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 		duo norm retained 1557 genes
# 			Preprocessing done: 0.05 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.07 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.27 mn
# 			Base louvain/leiden clus, searching ground truth: 0.03 mn
# 			Spectral clus: 0.07 mn
# 			Scoring: 0.02 mn
# 			Hubness methods full pipeline: 0.76 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 		duo norm retained 1644 genes
# 			Preprocessing done: 0.07 mn
# 			Inputs generated: 0.03 mn
# 			Scanpy louvain/leiden clus: 0.49 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.38 mn
# 			Base louvain/leiden clus, searching ground truth: 0.02 mn
# 			Spectral clus: 0.48 mn
# 			Scoring: 0.02 mn
# 			Hubness methods full pipeline: 2.3 mn
# 		sce_filteredHVG10_Zhengmix8eq.rds
# 		duo norm retained 1572 genes
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.02 mn
# 			Scanpy louvain/leiden clus: 0.22 mn
# 			Louvain/leiden clus: 0.01 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.24 mn
# 			Base louvain/leiden clus, searching ground truth: 0.06 mn
# 			Spectral clus: 0.17 mn
# 			Scoring: 0.03 mn
# 			Hubness methods full pipeline: 1.5 mn
# cosine 25 True duo False
# cosine 25 True seurat True
# 		sce_filteredHVG10_Koh.rds
# 		seurat norm retained 1130 genes
# 			Preprocessing done: 0.06 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.05 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.07 mn
# 		sce_filteredHVG10_KohTCC.rds
# 		seurat norm retained 15028 genes
# 			Preprocessing done: 0.2 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.01 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.06 mn
# 		sce_filteredHVG10_Kumar.rds
# 		seurat norm retained 922 genes
# 			Preprocessing done: 0.01 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.03 mn
# 		sce_filteredHVG10_KumarTCC.rds
# 		seurat norm retained 14872 genes
# 			Preprocessing done: 0.12 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.25 mn
# 		sce_filteredHVG10_SimKumar4easy.rds
# 		seurat norm retained 1032 genes
# 			Preprocessing done: 0.03 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.02 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.01 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.09 mn
# 		sce_filteredHVG10_SimKumar4hard.rds
# 		seurat norm retained 1041 genes
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.03 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.04 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.01 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.07 mn
# 		sce_filteredHVG10_SimKumar8hard.rds
# 		seurat norm retained 1016 genes
# 			Preprocessing done: 0.08 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.02 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.01 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.1 mn
# 		sce_filteredHVG10_Trapnell.rds
# 		seurat norm retained 997 genes
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.0 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.06 mn
# 		sce_filteredHVG10_TrapnellTCC.rds
# 		seurat norm retained 12191 genes
# 			Preprocessing done: 0.21 mn
# 			Inputs generated: 0.0 mn
# 			Scanpy louvain/leiden clus: 0.01 mn
# 			Louvain/leiden clus: 0.0 mn
# 			Scanpy louvain/leiden clus, searching ground truth: 0.01 mn
# 			Base louvain/leiden clus, searching ground truth: 0.0 mn
# 			Spectral clus: 0.0 mn
# 			Scoring: 0.0 mn
# 			Hubness methods full pipeline: 0.07 mn
# 		sce_filteredHVG10_Zhengmix4eq.rds
# 		seurat norm retained 294 genes
# 			Preprocessing done: 0.07 mn
# 			Inputs generated: 0.01 mn
# 			Scanpy louvain/leiden clus: 1.54 mn
# 			Louvain/leiden clus: 0.02 mn
# Cannot find the number of clusters
# Clustering solution from last iteration is used:72 at resolution 2.86102294921875e-06
# Cannot find the number of clusters
# Clustering solution from last iteration is used:72 at resolution 2.86102294921875e-06
# 			Scanpy louvain/leiden clus, searching ground truth: 12.19 mn
# Cannot find the number of clusters
# Clustering solution from last iteration is used:29 at resolution 2.86102294921875e-06
# Cannot find the number of clusters
# Clustering solution from last iteration is used:29 at resolution 2.86102294921875e-06
# 			Base louvain/leiden clus, searching ground truth: 0.1 mn
# 			Spectral clus: 0.12 mn
# 			Scoring: 0.01 mn
# 			Hubness methods full pipeline: 0.81 mn
# 		sce_filteredHVG10_Zhengmix4uneq.rds
# 		seurat norm retained 253 genes
# 			Preprocessing done: 0.02 mn
# 			Inputs generated: 0.05 mn
# 			Scanpy louvain/leiden clus: 2.22 mn
# 			Louvain/leiden clus: 0.01 mn
# Cannot find the number of clusters
# Clustering solution from last iteration is used:69 at resolution 2.86102294921875e-06
