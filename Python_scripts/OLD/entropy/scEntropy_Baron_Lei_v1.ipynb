# %%
# https://github.com/jzlei/scEntropy

# %%
import scEntropy.scEntropy as scEntropy 
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
data_file_path = '/Users/elise/Desktop/GitHub/Hubness_sc/data/Baron/data.csv'
data = pd.read_csv(data_file_path, index_col=0, header=0, sep=";")
print(data.shape)
print(np.mean(np.sum(data,axis=0)))
print(np.mean(np.sum(data!=0,axis=0)))
data.head(5)
# Out:
# (14466, 1883)
# 4962.103027084439
# 1636.0154009559215
#                 mouse1_lib1.final_cell_0001  mouse1_lib1.final_cell_0002  \
# X0610007P14Rik                            0                            2
# X0610009B22Rik                            0                            0
# X0610009E02Rik                            0                            0
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            0
#
#                 mouse1_lib1.final_cell_0003  mouse1_lib1.final_cell_0004  \
# X0610007P14Rik                            0                            0
# X0610009B22Rik                            0                            0
# X0610009E02Rik                            1                            0
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            1
#
#                 mouse1_lib1.final_cell_0005  mouse1_lib1.final_cell_0006  \
# X0610007P14Rik                            1                            0
# X0610009B22Rik                            1                            0
# X0610009E02Rik                            0                            0
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            1
#
#                 mouse1_lib1.final_cell_0007  mouse1_lib1.final_cell_0008  \
# X0610007P14Rik                            0                            1
# X0610009B22Rik                            0                            0
# X0610009E02Rik                            1                            1
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            0
#
#                 mouse1_lib1.final_cell_0009  mouse1_lib1.final_cell_0010  ...  \
# X0610007P14Rik                            0                            0  ...
# X0610009B22Rik                            0                            0  ...
# X0610009E02Rik                            0                            0  ...
# X0610009L18Rik                            0                            0  ...
# X0610009O20Rik                            1                            0  ...
#
#                 mouse2_lib3.final_cell_0386  mouse2_lib3.final_cell_0387  \
# X0610007P14Rik                            0                            1
# X0610009B22Rik                            0                            0
# X0610009E02Rik                            0                            0
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            0
#
#                 mouse2_lib3.final_cell_0388  mouse2_lib3.final_cell_0389  \
# X0610007P14Rik                            0                            0
# X0610009B22Rik                            0                            0
# X0610009E02Rik                            0                            0
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            0
#
#                 mouse2_lib3.final_cell_0390  mouse2_lib3.final_cell_0391  \
# X0610007P14Rik                            0                            0
# X0610009B22Rik                            0                            0
# X0610009E02Rik                            0                            0
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            0
#
#                 mouse2_lib3.final_cell_0392  mouse2_lib3.final_cell_0393  \
# X0610007P14Rik                            0                            0
# X0610009B22Rik                            0                            0
# X0610009E02Rik                            0                            0
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            0
#
#                 mouse2_lib3.final_cell_0394  mouse2_lib3.final_cell_0395
# X0610007P14Rik                            0                            0
# X0610009B22Rik                            0                            0
# X0610009E02Rik                            0                            0
# X0610009L18Rik                            0                            0
# X0610009O20Rik                            0                            0
#
# [5 rows x 1883 columns]

# %%
scentropy = scEntropy.scEntropy(data, ref_vec=None, option='predefined')

# %%
plt.plot(scentropy)
plt.show;

# %%
np.savetxt('/Users/elise/Desktop/GitHub/Hubness_sc/data/Baron/entropy_lei/baron_scentropy_v1.csv',
             scentropy)

# %%
plt.hist(scentropy)
plt.show;
